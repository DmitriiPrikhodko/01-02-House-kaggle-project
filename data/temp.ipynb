# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import shap
import joblib

from sklearn.metrics import *
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.inspection import permutation_importance

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_regression, chi2
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler,
    RobustScaler,
    MinMaxScaler,
    OrdinalEncoder,
    TargetEncoder,
    FunctionTransformer,
)

sklearn.set_config(transform_output="pandas")

from sklearn.ensemble import RandomForestRegressor

from catboost import CatBoostRegressor

import lightgbm as lgb

import xgboost as xgb

from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold

# for model learning
from sklearn.model_selection import (
    train_test_split,
    RandomizedSearchCV,
    cross_val_score,
)

# tunning hyperparamters model
import optuna

# %%
test = pd.read_csv("test.csv")

# %%
one_row = pd.DataFrame(test.iloc[45, :].copy()).T
# one_row = test.iloc[60, :].copy()
one_row
# Out:
#       Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 45  1506         20       RL         NaN   10456   Pave   NaN      IR1
#
#    LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 45         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#    MiscVal MoSold YrSold SaleType SaleCondition
# 45       0      5   2010       WD        Normal
#
# [1 rows x 80 columns]

# %%
one_row.to_csv("one_row.csv", index=False)

# %%
ten_rows = test.iloc[45:55, :].copy()
ten_rows
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 45  1506          20       RL          NaN    10456   Pave   NaN      IR1
# 46  1507          60       RL         80.0    10791   Pave   NaN      Reg
# 47  1508          50       RL          NaN    18837   Pave   NaN      IR1
# 48  1509          60       RL         80.0     9600   Pave   NaN      Reg
# 49  1510          20       RL         80.0     9600   Pave   NaN      Reg
# 50  1511          20       RL         90.0     9900   Pave   NaN      Reg
# 51  1512          20       RL         88.0     9680   Pave   NaN      Reg
# 52  1513          80       RL          NaN    10600   Pave  Pave      IR1
# 53  1514          90       RL         98.0    13260   Pave   NaN      IR1
# 54  1515          50       RL         68.0     9724   Pave   NaN      Reg
#
#    LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
# ten_rows.to_csv("ten_rows.csv", index=False)

# %%
three_rows = test.iloc[45:48, :].copy()
three_rows
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 45  1506          20       RL          NaN    10456   Pave   NaN      IR1
# 46  1507          60       RL         80.0    10791   Pave   NaN      Reg
# 47  1508          50       RL          NaN    18837   Pave   NaN      IR1
#
#    LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 45         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 46         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 47         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition
# 45       0      5    2010        WD         Normal
# 46       0      3    2010        WD         Normal
# 47       0      4    2010        WD         Normal
#
# [3 rows x 80 columns]

# %%
# three_rows.to_csv("three_rows.csv", index=False)

# %%
ddd = pd.read_csv("one_row.csv")
ddd
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 0  1506          20       RL          NaN    10456   Pave    NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      5    2010        WD         Normal
#
# [1 rows x 80 columns]
